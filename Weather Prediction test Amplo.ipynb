# %%
from Amplo import Pipeline
from sklearn.datasets import make_classification
from sklearn.datasets import make_regression
import pandas as pd
import numpy as np
np.random.seed(1)
# Out:
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.

# %%
data = pd.read_csv('C:\\Users\\Faisa_k2n8tj8\\OneDrive\\Desktop\\weather.csv')
print(data.head())

x = data.drop(["Data.Temperature.Avg Temp"], axis = 1)
y = data["Data.Temperature.Avg Temp"]
# Out:
#    Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                0.00  2016-01-03           1             3       2016
# 1                0.00  2016-01-03           1             3       2016
# 2                0.16  2016-01-03           1             3       2016
# 3                0.00  2016-01-03           1             3       2016
# 4                0.01  2016-01-03           1             3       2016
#
#   Station.City Station.Code Station.Location Station.State  \
# 0   Birmingham          BHM   Birmingham, AL       Alabama
# 1   Huntsville          HSV   Huntsville, AL       Alabama
# 2       Mobile          MOB       Mobile, AL       Alabama
# 3   Montgomery          MGM   Montgomery, AL       Alabama
# 4    Anchorage          ANC    Anchorage, AK        Alaska
#
#    Data.Temperature.Avg Temp  Data.Temperature.Max Temp  \
# 0                         39                         46
# 1                         39                         47
# 2                         46                         51
# 3                         45                         52
# 4                         34                         38
#
#    Data.Temperature.Min Temp  Data.Wind.Direction  Data.Wind.Speed
# 0                         32                   33             4.33
# 1                         31                   32             3.86
# 2                         41                   35             9.73
# 3                         38                   32             6.86
# 4                         29                   19             7.80

# %%
x, y = make_regression()
pipeline = Pipeline()
pipeline.fit(x, y)
yp = pipeline.predict(x)

print(yp)
# Out:
# *** Starting Amplo AutoML - AutoML ***
#
#
# [AutoML] Starting Feature Processor
# [AutoML] Analysing co-linearity
# [AutoML] Removed 0 Co-Linear features (0.999 %% threshold)
# [AutoML] Analysing datetime features
# [AutoML] Added 0 datetime features
# [AutoML] Analysing cross features
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:10<00:00,  9.91it/s]
# [AutoML] Added 1 cross features
# [AutoML] Calculating and Analysing K-Means features
# 100%|█████████████████████████████████████████████████████████████████████████████████| 16/16 [00:00<00:00, 411.36it/s]
# [AutoML] Analysing Trigonometric Features
# 100%|███████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 378.32it/s]
# [AutoML] Added 0 trigonometric features
# [AutoML] Analysing Inverse Features
# [AutoML] Added 2 inverse features.
# [AutoML] Diff features skipped, max diff = 0
# [AutoML] Added 0 differenced features
# [AutoML] Lagged features skipped, max lags = 0
# [AutoML] Added 0 lagged features
# [AutoML] Analysing features with a Random Forest
# [AutoML] Selected 38 features with 85.0% RF threshold
# [AutoML] Selected 25 features with 0.5% RF increment
# [AutoML] Analysing features with Shapely Additive Explanations
# [AutoML] Selected 39 features with 85.0% Shap threshold
# [AutoML] Selected 5 features with 5.0% Shap increment
# [AutoML] Initial Modelling for RFT features (38)
# [AutoML] Splitting data (shuffle=True, splits=3, features=38)
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [AutoML] LinearRegression               neg_mean_absolute_error: -41.2153        ± 1.2407         , training time: 0.0 s
# [AutoML] SVR                            neg_mean_absolute_error: -149.0529       ± 16.9141        , training time: 0.0 s
# [AutoML] BaggingRegressor               neg_mean_absolute_error: -105.8055       ± 10.1924        , training time: 0.0 s
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [AutoML] XGBRegressor                   neg_mean_absolute_error: -115.5850       ± 22.9005        , training time: 0.4 s
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [AutoML] CatBoostRegressor              neg_mean_absolute_error: -100.9056       ± 13.2312        , training time: 1.0 s
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [AutoML] RandomForestRegressor          neg_mean_absolute_error: -109.7660       ± 19.6580        , training time: 0.1 s
# [AutoML] Initial Modelling for RFI features (25)
# [AutoML] Splitting data (shuffle=True, splits=3, features=25)
# [AutoML] LinearRegression               neg_mean_absolute_error: -139.2791       ± 4.5315         , training time: 0.0 s
# [AutoML] SVR                            neg_mean_absolute_error: -153.9548       ± 10.3017        , training time: 0.0 s
# [AutoML] BaggingRegressor               neg_mean_absolute_error: -134.6499       ± 6.0062         , training time: 0.0 s
# [AutoML] XGBRegressor                   neg_mean_absolute_error: -136.2848       ± 17.4606        , training time: 0.0 s
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [AutoML] CatBoostRegressor              neg_mean_absolute_error: -135.9204       ± 10.1550        , training time: 0.1 s
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [AutoML] RandomForestRegressor          neg_mean_absolute_error: -128.6553       ± 6.6585         , training time: 0.1 s
# [AutoML] Initial Modelling for ShapThreshold features (39)
# [AutoML] Splitting data (shuffle=True, splits=3, features=39)
# [AutoML] LinearRegression               neg_mean_absolute_error: -42.8863        ± 1.2582         , training time: 0.0 s
# [AutoML] SVR                            neg_mean_absolute_error: -152.1741       ± 12.5586        , training time: 0.0 s
# [AutoML] BaggingRegressor               neg_mean_absolute_error: -114.7776       ± 19.1603        , training time: 0.0 s
# [AutoML] XGBRegressor                   neg_mean_absolute_error: -122.4898       ± 11.3567        , training time: 0.0 s
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [AutoML] CatBoostRegressor              neg_mean_absolute_error: -102.9759       ± 5.9540         , training time: 0.6 s
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [AutoML] RandomForestRegressor          neg_mean_absolute_error: -104.5283       ± 19.9028        , training time: 0.1 s
# [AutoML] Initial Modelling for ShapIncrement features (5)
# [AutoML] Splitting data (shuffle=True, splits=3, features=5)
# [AutoML] LinearRegression               neg_mean_absolute_error: -47.8823        ± 1.6149         , training time: 0.0 s
# [AutoML] SVR                            neg_mean_absolute_error: -153.1031       ± 10.6404        , training time: 0.0 s
# [AutoML] BaggingRegressor               neg_mean_absolute_error: -95.3750        ± 4.0651         , training time: 0.0 s
# [AutoML] XGBRegressor                   neg_mean_absolute_error: -96.1874        ± 6.3669         , training time: 0.0 s
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [AutoML] CatBoostRegressor              neg_mean_absolute_error: -67.0673        ± 7.4685         , training time: 0.4 s
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [I 2022-04-06 04:01:47,710] A new study created in memory with name: no-name-3c6b5505-eb6d-4a4d-a7f4-7d9a9ad08cbc
# [I 2022-04-06 04:01:47,742] Trial 0 finished with value: -32.741570383553196 and parameters: {}. Best is trial 0 with value: -32.741570383553196.
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [AutoML] RandomForestRegressor          neg_mean_absolute_error: -82.2826        ± 15.0785        , training time: 0.1 s
#
# [AutoML] Starting Hyper Parameter Optimization for LinearRegression on RFT features (100 samples, 38 features)
# [AutoML] Creating Documentation for LinearRegression - RFT
# [AutoML] Mean Absolute Error:            53.54 ± 15.17
# [AutoML] Mean Squared Error:             4616.84 ± 3125.53
# [AutoML] R2 Score:                       0.83 ± 0.09
# [AutoML] Max Error:                      119.75 ± 39.88
# [AutoML] Mean Absolute Percentage Error: 0.81 ± 0.24
# This figure was using constrained_layout, but that is incompatible with subplots_adjust and/or tight_layout; disabling constrained_layout.
# [I 2022-04-06 04:02:05,507] A new study created in memory with name: no-name-85b83f61-e6fd-4870-918e-9561331d276d
# [I 2022-04-06 04:02:05,536] Trial 0 finished with value: -39.499988411472614 and parameters: {}. Best is trial 0 with value: -39.499988411472614.
# [AutoML] Starting Hyper Parameter Optimization for LinearRegression on ShapThreshold features (100 samples, 39 features)
# [AutoML] Creating Documentation for LinearRegression - ShapThreshold
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [AutoML] Mean Absolute Error:            50.92 ± 10.61
# [AutoML] Mean Squared Error:             3985.93 ± 1808.88
# [AutoML] R2 Score:                       0.87 ± 0.06
# [AutoML] Max Error:                      110.53 ± 29.81
# [AutoML] Mean Absolute Percentage Error: 0.72 ± 0.36
# [I 2022-04-06 04:02:22,787] A new study created in memory with name: no-name-ffb7e4c4-b4ab-4eea-966b-2678818f4908
# [I 2022-04-06 04:02:22,808] Trial 0 finished with value: -50.59784937858289 and parameters: {}. Best is trial 0 with value: -50.59784937858289.
# [AutoML] Starting Hyper Parameter Optimization for LinearRegression on ShapIncrement features (100 samples, 5 features)
# [AutoML] Creating Documentation for LinearRegression - ShapIncrement
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# [AutoML] Mean Absolute Error:            46.39 ± 17.04
# [AutoML] Mean Squared Error:             3843.83 ± 2965.37
# [AutoML] R2 Score:                       0.88 ± 0.10
# [AutoML] Max Error:                      111.05 ± 39.02
# [AutoML] Mean Absolute Percentage Error: 0.58 ± 0.22
# [AutoML] All done :)
# [AutoML] Added 0 additive features
# [AutoML] Added 0 cross features
# [AutoML] Added 0 datetime features
# [AutoML] Added 0 differenced features
# [AutoML] Added 0 lagged features
# [AutoML] Added 0 trigonometric features
# [AutoML] Added 1 inverse features.
# [  84.52854   -236.84431     88.08312    134.67052    112.031166
#   144.00995    153.73143    -79.62169   -163.43596    534.6431
#   198.2341    -245.61569    101.40723   -302.3778    -240.2428
#   114.47609    -15.176533  -224.56465    478.68265    378.42963
#  -210.74884    164.58261   -103.247925    94.74924     35.168076
#   439.52252    -20.266798   -81.81332     72.46304     70.62275
#    32.82608     -2.044067   189.97401   -155.46906   -110.80823
#  -104.800415   150.40634     52.611298   153.79909    -38.649994
#  -239.51396    393.8875     -97.67933    140.54027   -158.18053
#   -58.471596    53.81936    -62.42343    -51.97811   -180.8057
#   -71.568504    17.26567    197.54121     78.75709    -34.424553
#    43.33293    357.6656       9.881441    19.995543  -123.16638
#  -216.63399    126.615425   351.36246   -389.16223     95.10312
#   217.61995     70.95195   -262.7486     312.139     -219.89877
#   -71.51025      5.2492213 -126.960075   -40.34852    341.86652
#  -172.87573   -141.20773    102.853714   158.70927    330.42047
#  -238.70483   -189.35535   -212.63362   -144.19034    -29.089872
#  -229.86517    -63.764862   -51.887856    62.427406  -101.88709
#   101.11456    345.35458    -47.150352   256.19287     13.259303
#   -99.630264   -78.47681     17.763077    36.528435  -157.7144   ]
